# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/m-bain/whisperX.git
# Out:
# fatal: destination path 'whisperX' already exists and is not an empty directory.

# %%
cd /content/drive/MyDrive/whisperX
# Out:
# /content/drive/MyDrive/whisperX

# %% [markdown]
# **install Requirement txt**

# %%
pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/whisperX
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 54.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.7/390.7 KB 39.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 102.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 KB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 94.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 KB 52.9 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-5nve__2w
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-5nve__2w
#   Resolved https://github.com/openai/whisper.git to commit 4e635c66441dfae3c6c72365f802293afffca3ef
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179331 sha256=5ecbe4b827e0d9c42a8230fffe7b0ac668c557bd20a0a9586eb339473505c5fd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g_bmcay_/wheels/a7/70/18/b7693c07b1d18b3dafb328f5d0496aa0d41a9c09ef332fd8e6
# Successfully built openai-whisper
# ...

# %% [markdown]
# **Install FFMPEG**

# %%
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:12 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# ...

# %% [markdown]
# **English**

# %%
# !whisperx examples/sample01.wav
# Out:
# 100%|████████████████████████████████████████| 461M/461M [00:04<00:00, 110MiB/s]
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100% 360M/360M [00:04<00:00, 88.3MB/s]
# Performing transcription...
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:02.000]  Oh, I'm okay. I will be.
# [00:02.000 --> 00:05.000]  I said she could stay with us, Mum. I just thought she feels better.
# [00:05.000 --> 00:07.000]  Yeah, of course she can.
# [00:07.000 --> 00:09.000]  Oh, this won't be for long.
# [00:09.000 --> 00:11.000]  Well, you can stay as long as you want, my love.
# [00:11.000 --> 00:13.000]  You really missed you.
# [00:13.000 --> 00:14.000]  Pops.
# [00:14.000 --> 00:16.000]  Great to see you, love.
# [00:16.000 --> 00:17.000]  Oh.
# ...

# %%
# !whisperx examples/sample01.wav --model tiny.en --vad_filter --align_model WAV2VEC2_ASR_LARGE_LV60K_960H
# Out:
# ...
# 100%|██████████████████████████████████████| 72.1M/72.1M [00:00<00:00, 105MiB/s]
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_large_lv60k_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_large_lv60k_asr_ls960.pth
# 100% 1.18G/1.18G [00:24<00:00, 50.7MB/s]
# Performing VAD...
# ~~ Transcribing VAD chunk: (00:00.000 --> 00:29.219) ~~
# [00:00.000 --> 00:02.000]  Hello.
# [00:02.000 --> 00:03.000]  Hello.
# [00:03.000 --> 00:04.000]  Hello.
# [00:04.000 --> 00:05.000]  Hello.
# [00:05.000 --> 00:06.000]  Hello.
# [00:06.000 --> 00:07.000]  Hello.
# [00:07.000 --> 00:08.000]  I'm OK.
# [00:08.000 --> 00:09.000]  I will be.
# [00:09.000 --> 00:11.000]  I said she could stay with us, ma'am.
# [00:11.000 --> 00:12.000]  Just as she feels better.
# [00:12.000 --> 00:13.000]  Oh, she can.
# [00:13.000 --> 00:15.000]  Oh, she's won't be for long.
# [00:15.000 --> 00:17.000]  Well, you can stay as long as you want.
# ...

# %%
# !whisperx examples/sample01.wav --model medium --vad_filter --align_model WAV2VEC2_ASR_LARGE_LV60K_960H
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:10<00:00, 146MiB/s]
# tcmalloc: large alloc 1528012800 bytes == 0x9b3b6000 @  0x7f4898785680 0x7f48987a6824 0x5f97c1 0x649901 0x5c43c6 0x4f327e 0x64e618 0x505163 0x56bbe1 0x5f5ee6 0x56bab6 0x569d8a 0x5f60c3 0x56cc92 0x5f5ee6 0x56bab6 0x569d8a 0x68e267 0x67d9b1 0x67da2f 0x67dad1 0x67fbf7 0x6b8082 0x6b840d 0x7f4898584083 0x5faa2e
# Performing VAD...
# ~~ Transcribing VAD chunk: (00:00.000 --> 00:29.219) ~~
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:02.000]  Ella.
# [00:02.000 --> 00:03.000]  How are you?
# [00:03.000 --> 00:04.000]  Love.
# [00:04.000 --> 00:05.000]  Oh.
# [00:05.000 --> 00:06.000]  How are you?
# [00:06.000 --> 00:08.000]  Oh, I'm OK.
# [00:08.000 --> 00:09.000]  I will be.
# [00:09.000 --> 00:10.000]  I said she could stay with us tomorrow,
# [00:10.000 --> 00:11.000]  just so she feels better.
# ...

# %% [markdown]
# **Persian**

# %% [markdown]
# **Get DataSet From HuggingFace**

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 17.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
from datasets import list_datasets, load_dataset
from pprint import pprint

datasets_list = list_datasets() 
pprint(datasets_list,compact=True)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'JaimeHernandez/jaimehdzphotos', 'trevfran/perfil', 'Nian/DreamBooth_Test',
#  'virfuji/connor', 'methoner/img', 'truongpdd/vslp_2016_uit_word_segment',
#  'leit/cc', 'Padomin/coraal-asr', 'joemmile/Lia',
#  'emoneil/reflections-in-peer-counseling', 'kunczs/draw_style',
#  'skytnt/anime-segmentation', 'ayesha08/pake2k', 'ayesha08/pake5k',
#  'Rolfro/Shark', 'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056852',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056853',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056854',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056855',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056856',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056857',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056858',
#  'autoevaluate/autoeval-eval-emotion-default-b33c36-1612056859',
# ...

# %%
dataset = load_dataset('common_voice','fa')
# Out:
# ...
# WARNING:datasets.download.download_manager:Computing checksums of downloaded files. They can be used for integrity verification. You can disable this by passing ignore_verifications=True to load_dataset
# ...
# Generating invalidated split:   0%|          | 0/11698 [00:00<?, ? examples/s]
# Dataset common_voice downloaded and prepared to /root/.cache/huggingface/datasets/common_voice/fa/6.1.0/a1dc74461f6c839bfe1e8cf1262fd4cf24297e3fbd4087a711bd090779023a5e. Subsequent calls will reuse this data.
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
print(f"👉 Dataset len(dataset): {len(dataset)}")
print("\n👉 First item 'dataset[0]':")
pprint(dataset['train'])
# Out:
# 👉 Dataset len(dataset): 6
#
# 👉 First item 'dataset[0]':
# Dataset({
#     features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#     num_rows: 7593
# })

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 7593
#     })
#     test: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 5213
#     })
#     validation: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 5213
#     })
#     other: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 22510
#     })
#     validated: Dataset({
#         features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment'],
#         num_rows: 251659
# ...

# %%
# Or get slices with several examples:
print("\n👉Slice of the two items 'dataset[10:12]':")
pprint(dataset['train']['audio'])
# Out:
# Streaming output truncated to the last 5000 lines.
#   'sampling_rate': 48000},
#  {'array': array([ 0.0000000e+00,  4.3126418e-14, -1.8672672e-16, ...,
#         3.3252991e-07,  4.9133985e-07,  8.3890455e-08], dtype=float32),
#   'path': '/root/.cache/huggingface/datasets/downloads/extracted/3b0e0ce56990e1c035c009dd3032760da75614498aab0a4090ea91c8d4e8a843/cv-corpus-6.1-2020-12-11/fa/clips/common_voice_fa_23713726.mp3',
#   'sampling_rate': 48000},
#  {'array': array([ 0.0000000e+00, -3.3857930e-14, -1.7956780e-14, ...,
#         5.1054503e-06, -1.6895583e-06, -3.0443393e-06], dtype=float32),
#   'path': '/root/.cache/huggingface/datasets/downloads/extracted/3b0e0ce56990e1c035c009dd3032760da75614498aab0a4090ea91c8d4e8a843/cv-corpus-6.1-2020-12-11/fa/clips/common_voice_fa_23713727.mp3',
#   'sampling_rate': 48000},
#  {'array': array([ 0.0000000e+00, -3.0736535e-13, -1.6106154e-13, ...,
#         1.2761238e-06,  1.5162623e-06,  4.4175795e-07], dtype=float32),
# ...

# %%
from IPython.display import Audio, display

sound_file='/root/.cache/huggingface/datasets/downloads/extracted/3b0e0ce56990e1c035c009dd3032760da75614498aab0a4090ea91c8d4e8a843/cv-corpus-6.1-2020-12-11/fa/clips/common_voice_fa_24072987.mp3'

display(Audio(sound_file, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !whisperx  /root/.cache/huggingface/datasets/downloads/extracted/3b0e0ce56990e1c035c009dd3032760da75614498aab0a4090ea91c8d4e8a843/cv-corpus-6.1-2020-12-11/fa/clips/common_voice_fa_24072987.mp3
# Out:
# Performing transcription...
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Persian
# [00:00.000 --> 00:04.540]  این پتو در تا بسان خونک و در زمستان گرمست
# New language found (fa)! Previous was (en), loading new alignment model for new language...
# Performing alignment...

# %%
# !whisperx /root/.cache/huggingface/datasets/downloads/extracted/3b0e0ce56990e1c035c009dd3032760da75614498aab0a4090ea91c8d4e8a843/cv-corpus-6.1-2020-12-11/fa/clips/common_voice_fa_24071976.mp3
# Out:
# Performing transcription...
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Persian
# [00:00.000 --> 00:03.000]  ایی بابا توما درد سر میگردی
# New language found (fa)! Previous was (en), loading new alignment model for new language...
# Performing alignment...

# %% [markdown]
# **France**

# %%
# !whisperx examples/sample_fr_01.wav --model tiny.en --vad_filter --align_model WAV2VEC2_ASR_LARGE_LV60K_960H
# Out:
# Performing VAD...
# ~~ Transcribing VAD chunk: (00:00.000 --> 00:28.055) ~~
# [00:00.720 --> 00:03.320]  So I'll watch these videos again again.
# [00:04.420 --> 00:05.240]  Thank you very much!
# [00:08.500 --> 00:09.780]  Thank you very much!
# [00:14.920 --> 00:14.920]  Today I'll show you where a few of these shit were
# [00:09.340 --> 00:10.180]  Okay,
# [00:11.840 --> 00:12.980]  oh, Buddha,
# [00:13.840 --> 00:15.380]  Ready, message,
# [00:15.380 --> 00:16.160]  ow,
# [00:16.160 --> 00:16.960]  Willakie!
# [00:22.060 --> 00:22.800]  I'll die.
# [00:22.800 --> 00:23.640]  Oh no
# [00:23.640 --> 00:24.620]  I can't wait,
# [00:24.620 --> 00:27.160]  swatch him to give him a suction.
# [00:27.160 --> 00:29.160]  summer
# ~~ Transcribing VAD chunk: (00:34.535 --> 00:59.037) ~~
# [00:00.000 --> 00:04.000]  I don't know if you'll see him.
# [00:04.000 --> 00:07.000]  Don't be a communist, wealthy brother.
# [00:06.900 --> 00:08.660]  Like two songs.
# ...

# %% [markdown]
# **Italian**

# %%
# !whisperx --model tiny --language it examples/sample_it_01.wav
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_voxpopuli_base_10k_asr_it.pt" to /root/.cache/torch/hub/checkpoints/wav2vec2_voxpopuli_base_10k_asr_it.pt
# 100% 360M/360M [00:05<00:00, 70.9MB/s]
# Performing transcription...
# [00:00.000 --> 00:03.000]  Signori, piacciere.
# [00:03.000 --> 00:05.000]  Lì avvicite la vedeta amirata
# [00:05.000 --> 00:07.000]  Tattutino ecco di salgemo a provera
# [00:07.000 --> 00:09.000]  della nostra cultura seranno naturalmente
# [00:09.000 --> 00:10.000]  a coltisuto la mia protezione
# [00:10.000 --> 00:12.000]  per la durata del loro soggiardo.
# [00:15.000 --> 00:16.000]  Grazie.
# [00:17.000 --> 00:18.000]  Corlomi?
# [00:18.000 --> 00:20.000]  Lo pronuncio correttamente?
# [00:21.000 --> 00:22.000]  Si.
# [00:22.000 --> 00:23.000]  Greta.
# [00:23.000 --> 00:25.000]  Corlomi?
# [00:25.000 --> 00:28.000]  Per costessia me lo repete ancora.
# [00:28.000 --> 00:34.000]  Gordlami, scusico me, Gordlami.
# ...

# %% [markdown]
# **German**

# %%
# !whisperx --model tiny --language de examples/sample_de_01.wav
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_voxpopuli_base_10k_asr_de.pt" to /root/.cache/torch/hub/checkpoints/wav2vec2_voxpopuli_base_10k_asr_de.pt
# 100% 360M/360M [00:05<00:00, 67.5MB/s]
# Performing transcription...
# [00:00.000 --> 00:02.000]  Weilerein von Hamas-Mann.
# [00:06.000 --> 00:08.000]  Wo war das Lande jetzt lange her?
# [00:09.000 --> 00:11.000]  Schneidig, eh und hier.
# [00:14.000 --> 00:16.000]  Also, was ist mit ihrem wunderschönen Bein geschehen?
# [00:17.000 --> 00:21.000]  Ein Nebenprodukt der Arsch dritte, die sind eine deutsche Filmwelt aus der Zweifelzone.
# [00:22.000 --> 00:24.000]  Sparen Sie sich regulante Sie, Alter Hund.
# [00:24.000 --> 00:27.000]  Ich kenne zu viele von ihren früheren Eroberungen,
# [00:27.000 --> 00:29.600]  dass ich Ihnen hier an Monichtopf treten könnte.
# [00:29.600 --> 00:31.000]  Nein, ich muss es etwas hier.
# [00:32.000 --> 00:34.000]  Ja, ich habe mich,
# ...

# %%
cd /content/drive/MyDrive/whisperX/
# Out:
# /content/drive/MyDrive/whisperX

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/drive/MyDrive/whisperX/examples/sample01.mp4','rb').read()
data_url = "data:/content/drive/MyDrive/whisperX/examples/sample01.mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:/content/drive/MyDrive/whisperX/examples/sample01.mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# **Tokenize**

# %%
import whisperx

device = "cuda" 
audio_file = "/content/drive/MyDrive/whisperX/examples/sample01.mp4"

# transcribe with original whisper
model = whisperx.load_model("tiny", device)
result = model.transcribe(audio_file)

print(result["segments"]) # before alignment

# load alignment model and metadata
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)

# align whisper output
result_aligned = whisperx.align(result["segments"], model_a, metadata, audio_file, device)

print(result_aligned["segments"]) # after alignment
print(result_aligned["word_segments"]) # after alignment
# Out:
# [{'id': 0, 'seek': 0, 'start': 0.0, 'end': 2.0, 'text': ' Hello.', 'tokens': [2425, 13], 'temperature': 0.0, 'avg_logprob': -0.5737967731283723, 'compression_ratio': 1.5569620253164558, 'no_speech_prob': 0.17410407960414886}, {'id': 1, 'seek': 0, 'start': 2.0, 'end': 3.0, 'text': ' Hello.', 'tokens': [2425, 13], 'temperature': 0.0, 'avg_logprob': -0.5737967731283723, 'compression_ratio': 1.5569620253164558, 'no_speech_prob': 0.17410407960414886}, {'id': 2, 'seek': 0, 'start': 3.0, 'end': 5.0, 'text': " Hi, I'm Lou.", 'tokens': [2421, 11, 286, 478, 7272, 13], 'temperature': 0.0, 'avg_logprob': -0.5737967731283723, 'compression_ratio': 1.5569620253164558, 'no_speech_prob': 0.17410407960414886}, {'id': 3, 'seek': 0, 'start': 5.0, 'end': 6.0, 'text': ' Hi.', 'tokens': [2421, 13], 'temperature': 0.0, 'avg_logprob': -0.5737967731283723, 'compression_ratio': 1.5569620253164558, 'no_speech_prob': 0.17410407960414886}, {'id': 4, 'seek': 0, 'start': 6.0, 'end': 8.0, 'text': " Oh, I'm OK.", 'to
# ...

# %% [markdown]
# **Whisper**

# %%
# !pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Preparing metadata (setup.py) ... done

# %%
# !pip install pytube -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 3.2 MB/s eta 0:00:00

# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pytube import YouTube
yt = YouTube('https://www.youtube.com/watch?v=ft-nV2MJPfY')
print(yt.title)
# Out:
# برنامه نویسی - آموزش زبان برنامه نویسی پایتون از صفر تا صد

# %%
import os 
import subprocess 

def video2mp3(video_file, output_ext="wav"):
    filename, ext = os.path.splitext(video_file)
    subprocess.call(["ffmpeg", "-y", "-i", video_file, f"{filename}.{output_ext}"],stdout=subprocess.DEVNULL,stderr=subprocess.STDOUT)
    return f"{filename}.{output_ext}"

# %%
input_video = '/content/drive/MyDrive/whisperX/examples/sample01.mp4'
audio_file = video2mp3(input_video)

# %%
import whisper
model = whisper.load_model('medium')
model.transcribe(audio_file,fp16=False)['text']
# Out:
# " Ella. How are you? Love. Oh. How are you? Oh, I'm OK. I will be. I said she could stay with us, Mara, just till she feels better. Yeah, of course she can. No, this won't be for long. Well, you can stay as long as you want, my love. I really missed you. Pops. Great to see you, love. Oh. All right, shall we get you off to bed, then? You should have given me some warning. I know. I put the electric blanket on. I'm sorry. All right, Dala. Freeze a bit. I'm sorry. All right, Dala. Freeze and up there. In a bedroom, Peter unpacks her suitcase. The middle-aged woman opens her green case. Do you want your PJs? Yeah. Yeah. Lifting a bundle of pajamas, Peter finds a sheet of paper labeled, Lancaster North Hospital, discharge sheet. He closes the suitcase and brings Gloria the pajamas. There you go. Thank you. He picks up the locket. He kept it. Oh, cool."

# %%
def translate(audio):
    options = dict(beam_size=5, best_of=5)
    translate_options = dict(task='translate', **options)
    result = model.transcribe(audio_file,**translate_options)
    return result
result = translate(audio_file)
print(result["text"])
# Out:
#  Bella. How are you, love? Oh. How are you? Oh, I'm OK. I will be. I said she could stay with us, Mara, just so she feels better. Yeah, of course she can. No, this won't be for long. Well, you can stay as long as you want, my love. I really missed you. Pops. Great to see you, love. Oh. All right, shall we get you off to bed, then? You should have given me some warning as I put the electric blanket on. I'm sorry. All right, Dala. Please, I'm not there. In a bedroom, Peter unpacks her suitcase. The middle-aged woman opens her green case. Do you want your PJs? Yeah. Yeah. Lifting a bundle of pajamas, Peter finds a sheet of paper labeled Lancaster North Hospital discharge sheet. He closes the suitcase and brings glory of the pajamas. There you go. Thank you. He picks up the locket. He kept it. Oh, of course.
